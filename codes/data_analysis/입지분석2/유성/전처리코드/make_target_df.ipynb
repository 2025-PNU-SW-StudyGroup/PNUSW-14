# %%
import chardet
import pandas as pd
import numpy as np
from scipy.spatial import distance

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

def open_with_auto_sensing_encoding_types(file_path):
    with open(file_path, 'rb') as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        encoding_type = result['encoding']

    print(f"파일의 인코딩: {encoding_type}")
    # 감지된 인코딩으로 파일 읽기
    df = pd.read_csv(file_path, encoding=encoding_type)
    print(len(df))
    return df

# %%
cur_target_path = "/Users/yujin/Desktop/파일/3-1/데이터분석 공모전/codes/키즈카페입지분석2/data/target/grid_parking_summary_with_distance.csv"
cur_target_df = open_with_auto_sensing_encoding_types(cur_target_path)
cur_target_df
# Out:
# 파일의 인코딩: UTF-8-SIG
# 1765
#        행정동  center_lat  center_lon  주차장수 주차장정보  최소거리주차장_경도  최소거리주차장_위도  \
# 0     자양4동   37.529359  127.057131   0.0    []         NaN         NaN
# 1     자양4동   37.528462  127.058268   0.0    []         NaN         NaN
# 2     자양4동   37.529363  127.058263   0.0    []         NaN         NaN
# 3     자양4동   37.530265  127.058257   0.0    []         NaN         NaN
# 4     자양4동   37.531166  127.058252   0.0    []         NaN         NaN
# ...    ...         ...         ...   ...   ...         ...         ...
# 1760   광장동   37.554795  127.113589   0.0    []         NaN         NaN
# 1761   광장동   37.555697  127.113584   0.0    []         NaN         NaN
# 1762   광장동   37.556598  127.113580   0.0    []         NaN         NaN
# 1763   광장동   37.557499  127.113575   0.0    []         NaN         NaN
# 1764   광장동   37.558401  127.113570   0.0    []         NaN         NaN
#
#       최소거리(km)  최소거리(m)
# 0          NaN      NaN
# 1          NaN      NaN
# ...

# %%
cur_target_df.columns
# Out:
# Index(['행정동', 'center_lat', 'center_lon', '주차장수', '주차장정보', '최소거리주차장_경도',
#        '최소거리주차장_위도', '최소거리(km)', '최소거리(m)'],
#       dtype='object')

# %%
target_df = cur_target_df[['행정동', 'center_lat', 'center_lon', '주차장수', '최소거리(m)']]
print(target_df.head(3))
# Out:
#     행정동  center_lat  center_lon  주차장수  최소거리(m)
# 0  자양4동   37.529359  127.057131   0.0      NaN
# 1  자양4동   37.528462  127.058268   0.0      NaN
# 2  자양4동   37.529363  127.058263   0.0      NaN

# %%
target_df['최소거리(m)'] = target_df['최소거리(m)'].fillna(0.0)
target_df.to_csv("/Users/yujin/Desktop/파일/3-1/데이터분석 공모전/codes/키즈카페입지분석2/data/target/final_targetV2.csv")
# Out:
# /var/folders/6q/q927ypwn4ll9d4rvjq9gl1qw0000gn/T/ipykernel_44953/829332464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_df['최소거리(m)'] = target_df['최소거리(m)'].fillna(0.0)
